# %%
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
df = pd.read_csv('data.csv')
df
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
train, valid, test = np.split(df.sample(frac=1), [int(0.6 * len(df)), int(0.8 * len(df))])
train
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 548           0                                           0.493248
# 6333          0                                           0.430312
# 6558          0                                           0.710915
# 1606          0                                           0.524204
# 3549          0                                           0.585921
# ...         ...                                                ...
# 3626          0                                           0.528494
# 5657          0                                           0.480330
# 6764          0                                           0.574952
# 4979          0                                           0.458148
# 228           0                                           0.491639
#
#        ROA(A) before interest and % after tax  \
# 548                                  0.550153
# 6333                                 0.494930
# ...

# %%
y_test = test.pop("Bankrupt?")
y_train = train.pop("Bankrupt?")
y_valid = valid.pop("Bankrupt?")
x_test = test
x_valid = valid
x_train = train

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(95),
    tf.keras.layers.Dense(428, activation='relu'),
    tf.keras.layers.Dense(524, activation='relu'),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
    ]
)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy')
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 128/128 [==============================] - 4s 21ms/step - loss: 14998080.0000
# Epoch 2/10
# 128/128 [==============================] - 3s 21ms/step - loss: 1773847.3750
# Epoch 3/10
# 128/128 [==============================] - 3s 23ms/step - loss: 650376.3750
# Epoch 4/10
# 128/128 [==============================] - 2s 19ms/step - loss: 216845.5625
# Epoch 5/10
# 128/128 [==============================] - 3s 22ms/step - loss: 93433.3047
# Epoch 6/10
# 128/128 [==============================] - 3s 20ms/step - loss: 61236.8633
# Epoch 7/10
# 128/128 [==============================] - 2s 19ms/step - loss: 47395.5078
# Epoch 8/10
# 128/128 [==============================] - 2s 18ms/step - loss: 8269.3350
# Epoch 9/10
# 128/128 [==============================] - 2s 19ms/step - loss: 6432.3530
# Epoch 10/10
# 128/128 [==============================] - 2s 18ms/step - loss: 1021.7518

# %%
pred = model.predict(x_valid)
pred.max
# Out:
# 43/43 [==============================] - 0s 7ms/step
# <function ndarray.max>

# %%
sit = []
for value in pred:
    if value > 0.5:
        sit.append(1)
    else:
        sit.append(0)

# %%
sit = np.array(sit)

# %%
sit.max()
# Out:
# 1

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 95)                9120
#
#  dense_1 (Dense)             (None, 1024)              98304
#
#  dense_2 (Dense)             (None, 1)                 1025
#
# ...
# Total params: 108,449
# Trainable params: 108,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred = model.predict(x_test)
pred
# Out:
# 43/43 [==============================] - 0s 3ms/step
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
def MSE(y_real, y_pred):
    return (np.square(y_real - y_pred)).mean()

# %%
MSE(y_train, sit)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 MSE(y_train, sit)
#
# Cell In[16], line 2, in MSE(y_real, y_pred)
#       1 def MSE(y_real, y_pred):
# ----> 2     return (np.square(y_real - y_pred)).mean()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\arraylike.py:110, in OpsMixin.__sub__(self, other)
#     108 @unpack_zerodim_and_defer("__sub__")
#     109 def __sub__(self, other):
# --> 110     return self._arith_method(other, operator.sub)
#
# ...

# %%
test = y_test.to_numpy
test
# Out:
# <bound method IndexOpsMixin.to_numpy of 5400    0
# 2550    0
# 3170    0
# 6270    0
# 4586    0
#        ..
# 997     0
# 6415    0
# 3588    0
# 2852    0
# 1480    0
# Name: Bankrupt?, Length: 1364, dtype: int64>

# %%
# Out:
# <bound method IndexOpsMixin.to_numpy of 5400    0
# 2550    0
# 3170    0
# 6270    0
# 4586    0
#        ..
# 997     0
# 6415    0
# 3588    0
# 2852    0
# 1480    0
# Name: Bankrupt?, Length: 1364, dtype: int64>
